# %% [markdown]
# # Aula 15 - Arquivos + Erros (Parte 2)

# %% [markdown]
# ## Exercício 1
# Dado um arquivo com medições de profundidade, conte quantas são maiores que a anterior.
# 💡 *Use lista e laço for.*

# %% [markdown]
# ## Exercício 2
# Faça uma votação para escolher entre Sushi (1) e Churrasco (2). Grave os votos em arquivo e depois apure o resultado.

# %% [markdown]
# ## Exercício 3
# Tente abrir um arquivo inexistente e trate a exceção.
