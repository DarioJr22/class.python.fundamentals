# %% [markdown]
# # Aula 15 - Exercícios

# %% [markdown]
# ### Exercício 1
# Contar quantas medições de profundidade aumentam em relação à anterior a partir de um arquivo.

# %% [markdown]
# ### Exercício 2
# Gravar votos de 10 pessoas em um .txt (1-Sushi, 2-Churrasco) e apurar resultado.
