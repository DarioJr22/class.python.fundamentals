# %% [markdown]
# # Exemplos - Aula 14

# %% [markdown]
# ```python
# with open('cachorros.txt', 'w') as f:
#     f.write('Nome: Rex Raça: Poodle\n')
# ```

# %% [markdown]
# ```python
# with open('cachorros.txt') as f:
#     print(f.read())
# ```
