# %% [markdown]
# # Aula 17 - Revisão + Try/Except/Else

# %% [markdown]
# ## Exercício 1
# Mesma lógica do vetor: quantos são maiores, menores e iguais ao primeiro número. Use try/except.

# %% [markdown]
# ## Exercício 2
# Use `try`, `except`, `else` para aprimorar a função de verificar número primo.

# %% [markdown]
# ## Exercício 3
# Testar abertura de arquivo com `try/except`, mostrando uma mensagem clara se o arquivo não existir.
