# %% [markdown]
# # Aula 17 - Exercícios

# %% [markdown]
# ### Exercício 1
# Melhorar verificar_primo usando try/except/else.

# %% [markdown]
# ### Exercício 2
# Abrir arquivo inexistente com tratamento amigável.
