# %% [markdown]
# # Exemplos - Aula 15

# %% [markdown]
# ```python
# with open('medicoes.txt') as f:
#     medidas = [int(l) for l in f]
#     print(sum(medidas[i] > medidas[i-1] for i in range(1, len(medidas))))
# ```

# %% [markdown]
# ```python
# with open('votos.txt') as f:
#     votos = [l.strip() for l in f]
#     print('Sushi:', votos.count('1'), 'Churrasco:', votos.count('2'))
# ```
