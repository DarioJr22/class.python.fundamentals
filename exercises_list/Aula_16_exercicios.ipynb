# %% [markdown]
# # Aula 16 - Exercícios

# %% [markdown]
# ### Exercício 1
# Pedir 10 números inteiros, comparar com o primeiro e contar maiores, menores e iguais com tratamento de erro.

# %% [markdown]
# ### Exercício 2
# Função verificar_primo com try/except para entrada inválida.
