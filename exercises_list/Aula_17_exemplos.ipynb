# %% [markdown]
# # Exemplos - Aula 17

# %% [markdown]
# ```python
# try:
#     with open('arquivo.txt') as f:
#         print(f.read())
# except FileNotFoundError:
#     print('Arquivo não encontrado.')
# ```
