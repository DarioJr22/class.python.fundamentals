# %% [markdown]
# # Exemplos - Aula 16

# %% [markdown]
# ```python
# try:
#     lista = [int(input()) for _ in range(10)]
#     ref = lista[0]
#     print('Maiores:', sum(n > ref for n in lista))
# except: print('Erro')
# ```
