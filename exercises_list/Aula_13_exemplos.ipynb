# %% [markdown]
# # Exemplos - Aula 13

# %% [markdown]
# ```python
# def filtrar_intervalo(lista, inf, sup): return [x for x in lista if inf <= x <= sup]
# ```

# %% [markdown]
# ```python
# n = 5
# print({i: i**2 for i in range(n+1)})
# ```

# %% [markdown]
# ```python
# cardapio = {'Café': 3.5}
# cardapio['Suco'] = 5
# cardapio['Café'] = 4
# del cardapio['Café']
# ```
